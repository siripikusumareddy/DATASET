# %% [markdown]
# <a href="https://colab.research.google.com/github/siripikusumareddy/DATASET/blob/main/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
# !pip install qiskit qiskit-aer pylatexenc matplotlib -q
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 60.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 74.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 73.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 2.8 MB/s eta 0:00:00
# ...

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector
import matplotlib.pyplot as plt

# %%
qc1=QuantumCircuit(1)

# %%
state1=Statevector(qc1)
display(plot_bloch_multivector(state1,title ="Program 1: |0> State"))

# %%
qc2=QuantumCircuit(1)
qc2.x(0)
state2=Statevector(qc2)
display(plot_bloch_multivector(state2,title='program 2 :Pauli-X -> |1> State'))

# %%
qc3=QuantumCircuit(1)
qc3.h(0)
state3=Statevector(qc3)
display(plot_bloch_multivector(state3, title="Program 3: Hadamard -> Superposition"))

# %%
qc4=QuantumCircuit(2)
qc4.y(0)
state4=Statevector(qc4)
display(plot_bloch_multivector(state4, title='program 4: Pauli-Y'))

# %%
qc5=QuantumCircuit(1)
qc5.z(0)
state5=Statevector(qc5)
display(plot_bloch_multivector(state5, title='program 5: Pauli - 2'))

# %%
qc6=QuantumCircuit(1)
qc6.h(0)
state6=Statevector(qc6)
display(plot_bloch_multivector(state6, title='Program 6: |+> state'))

# %%
qc7=QuantumCircuit(2)
qc7.h(0)
qc7.z(0)
state7=Statevector(qc7)
display(plot_bloch_multivector(state7 , title='Program 7: |-> state'))

# %%
qc8=QuantumCircuit(1)
qc8.h(0)
qc8.x(0)
state8=Statevector(qc8)
display(plot_bloch_multivector(state8, title='program 8:H folled by X'))

# %%
from qiskit.visualization import plot_bloch_multivector
from IPython.display import display

# Create a circuit with 3 qubits
qc_compare = QuantumCircuit(3)

# Apply gates
qc_compare.x(0)   # Pauli-X
qc_compare.y(1)   # Pauli-Y
qc_compare.z(2)   # Pauli-Z

# Get the statevector
state_compare = Statevector(qc_compare)

# Display Bloch spheres
display(
    plot_bloch_multivector(
        state_compare,
        title="Q0: Pauli-X | Q1: Pauli-Y | Q2: Pauli-Z"
    )
)
